# %%
import os
import argparse
import time
import datetime
from tqdm import tqdm

from munch import Munch
from torch.backends import cudnn
import torch
import torch.nn.functional as F
import numpy as np

from core.my_loader import get_train_loader, get_test_loader, InputFetcher
from core.my_solver import Solver
from torchvision.transforms import Compose, Resize, Normalize, ToTensor
from torchvision.datasets import ImageFolder
from torch.utils.data import Subset, DataLoader

from easydict import EasyDict as edict
from core.my_solver import compute_d_loss, compute_g_loss, moving_average, adv_loss, r1_reg, Sampler, LoaderSampler, tensor2img
from core.my_metrics import get_Z_pushed_loader_stats, calculate_cost
from core.fid_score import calculate_frechet_distance

from IPython.display import clear_output
import matplotlib.pyplot as plt

os.environ['CUDA_VISIBLE_DEVICES'] = "0"

def str2bool(v):
    return v.lower() in ('true')


def subdirs(dname):
    return [d for d in os.listdir(dname)
            if os.path.isdir(os.path.join(dname, d))]

lambda_id = 0.0

args = edict({
    'img_size': 128,
    'num_domains': 2,
    'latent_dim': 16,
    'hidden_dim': 512,
    'style_dim': 64, 
    'lambda_reg': 1.0,
    'lambda_cyc': 1.0,
    'lambda_sty': 1.0,
    'lambda_ds': 1.0,
    'lambda_id': lambda_id,
    'ds_iter': 100000,
    'w_hpf': -1.0,
    'randcrop_prob': 0.5,
    'total_iters': 100000,
    'resume_iter': 0,
    'batch_size': 8,
    'val_batch_size': 32,
    'lr': 1e-4,
    'f_lr': 1e-6,
    'beta1': 0.0,
    'beta2': 0.99,
    'weight_decay': 1e-4,
    'num_outs_per_domain': 10,
    'mode': 'train', 
    'num_workers': 4,
    'seed': 777,
    'train_img_dir': '/cache/selikhanovych/extremal_ot/stargan-v2/data/handbag2shoes_train',
    'val_img_dir': '/cache/selikhanovych/extremal_ot/stargan-v2/data/handbag2shoes_test',
    'sample_dir': 'expr/samples',
    'checkpoint_dir': f'/cache/selikhanovych/extremal_ot/stargan-v2/handbag2shoes_exps/checkpoints_lambda_{lambda_id}',
    'eval_dir': 'expr/eval',
    'result_dir': 'expr/results',
    'src_dir': 'assets/representative/celeba_hq/src',
    'ref_dir': 'assets/representative/celeba_hq/ref',
    'inp_dir': 'assets/representative/custom/female',
    'out_dir': 'assets/representative/celeba_hq/src/female',
    'wing_path': 'expr/checkpoints/wing.ckpt',
    'lm_path': 'expr/checkpoints/celeba_lm_mean.npz',
    'print_every': 10,
    'sample_every': 4000,
    'save_every': 4000,
    'eval_every': 4000,
    
    'target_dataset': 'shoes',
    'OUTPUT_PATH': f'/cache/selikhanovych/OT_competitors/stargan-v2/celeba2anime_exps/checkpoints_lambda_{lambda_id}',
    'domains': {
        'source': 'handbag',
        'target': 'shoes',
    },
    'train_a': '/cache/selikhanovych/extremal_ot/stargan-v2/data/handbag2shoes_train/handbag',
    'train_b': '/cache/selikhanovych/extremal_ot/stargan-v2/data/handbag2shoes_train/shoes', 
    'test_a': '/cache/selikhanovych/extremal_ot/stargan-v2/data/handbag2shoes_test/handbag',
    'test_b': '/cache/selikhanovych/extremal_ot/stargan-v2/data/handbag2shoes_test/shoes',
    
    'n_epochs': 1
})

os.system(f"mkdir -p {args.OUTPUT_PATH}")
os.system(f"mkdir -p {args.checkpoint_dir}")


eval_trg_domain = args.domains['target']
eval_src_domain = args.domains['source']

domains = os.listdir(args.val_img_dir)
domains.sort()


print(f"domains {domains}")
print(eval_trg_domain, eval_src_domain)

final_trg_index = -1
final_src_index = -1

for trg_idx, trg_domain in enumerate(domains):
    src_domains = [x for x in domains if x != trg_domain]
    for src_idx, src_domain in enumerate(src_domains):
        if src_domain == eval_src_domain and trg_domain == eval_trg_domain:
            final_trg_index = trg_idx
            final_src_index = src_idx
            
print(final_trg_index, final_src_index)

cudnn.benchmark = True
torch.manual_seed(args.seed)

solver = Solver(args)

assert len(subdirs(args.train_img_dir)) == args.num_domains
assert len(subdirs(args.val_img_dir)) == args.num_domains

loaders = Munch(src=get_train_loader(root=args.train_img_dir,
                                     which='source',
                                     img_size=args.img_size,
                                     batch_size=args.batch_size,
                                     num_workers=args.num_workers),
                ref=get_train_loader(root=args.train_img_dir,
                                     which='reference',
                                     img_size=args.img_size,
                                     batch_size=args.batch_size,
                                     num_workers=args.num_workers),
                val=get_test_loader(root=args.val_img_dir,
                                    img_size=args.img_size,
                                    batch_size=args.val_batch_size,
                                    shuffle=False,
                                    num_workers=args.num_workers))

device = 'cuda'

args = solver.args
nets = solver.nets
nets_ema = solver.nets_ema
optims = solver.optims

transform = Compose([Resize((args.img_size, args.img_size)),
                     ToTensor(),
                     Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset_a = ImageFolder(args.train_a, transform)
train_dataset_b = ImageFolder(args.train_b, transform)
test_dataset_a = ImageFolder(args.test_a, transform)
test_dataset_b = ImageFolder(args.test_b, transform)

train_loader_a = DataLoader(dataset=train_dataset_a,
                            batch_size=20,
                            num_workers=4,
                            pin_memory=True,
                            shuffle=False)

train_loader_b = DataLoader(dataset=train_dataset_b,
                            batch_size=20,
                            num_workers=4,
                            pin_memory=True,
                            shuffle=False)

test_loader_a = DataLoader(dataset=test_dataset_a,
                           batch_size=20,
                           num_workers=4,
                           pin_memory=True,
                           shuffle=False)

test_loader_b = DataLoader(dataset=test_dataset_b,
                           batch_size=20,
                           num_workers=4,
                           pin_memory=True,
                           shuffle=False)

X_sampler = LoaderSampler(train_loader_a)
X_test_sampler = LoaderSampler(test_loader_a)
Y_sampler = LoaderSampler(train_loader_b)
Y_test_sampler = LoaderSampler(test_loader_b)


torch.manual_seed(0xBADBEEF)
np.random.seed(0xBADBEEF)
solver.X_fixed = X_sampler.sample(10)
solver.Y_fixed = Y_sampler.sample(10)

solver.X_test_fixed = X_test_sampler.sample(10)
solver.Y_test_fixed = Y_test_sampler.sample(10)

# fetch random validation images for debugging
fetcher = InputFetcher(loaders.src, loaders.ref, args.latent_dim, 'train')
fetcher_val = InputFetcher(loaders.val, None, args.latent_dim, 'val')
inputs_val = next(fetcher_val)

# resume training if necessary
if args.resume_iter > 0:
    solver._load_checkpoint(args.resume_iter)

# remember the initial value of ds weight
initial_lambda_ds = args.lambda_ds
print(f"lambda id = {args.lambda_id}")
# Out:
# domains ['handbag', 'shoes']
# shoes handbag
# 1 0
# Number of parameters of generator: 33632003
# Number of parameters of mapping_network: 2438272
# Number of parameters of style_encoder: 20799744
# Number of parameters of discriminator: 20735106
# Initializing generator...
# Initializing mapping_network...
# Initializing style_encoder...
# Initializing discriminator...
# Preparing DataLoader to fetch source images during the training phase...
# Preparing DataLoader to fetch reference images during the training phase...
# Preparing DataLoader for the generation phase...
# lambda id = 0.0

# %%
os.environ['CUDA_VISIBLE_DEVICES']
# Out:
# '0'

# %%
device = 'cuda'

args = solver.args
nets = solver.nets
nets_ema = solver.nets_ema
optims = solver.optims

transform = Compose([Resize((args.img_size, args.img_size)),
                     ToTensor(),
                     Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

train_dataset_a = ImageFolder(args.train_a, transform)
train_dataset_b = ImageFolder(args.train_b, transform)
test_dataset_a = ImageFolder(args.test_a, transform)
test_dataset_b = ImageFolder(args.test_b, transform)

train_loader_a = DataLoader(dataset=train_dataset_a,
                            batch_size=20,
                            num_workers=4,
                            pin_memory=True,
                            shuffle=False)

train_loader_b = DataLoader(dataset=train_dataset_b,
                            batch_size=20,
                            num_workers=4,
                            pin_memory=True,
                            shuffle=False)

test_loader_a = DataLoader(dataset=test_dataset_a,
                           batch_size=20,
                           num_workers=4,
                           pin_memory=True,
                           shuffle=False)

test_loader_b = DataLoader(dataset=test_dataset_b,
                           batch_size=20,
                           num_workers=4,
                           pin_memory=True,
                           shuffle=False)

X_sampler = LoaderSampler(train_loader_a)
X_test_sampler = LoaderSampler(test_loader_a)
Y_sampler = LoaderSampler(train_loader_b)
Y_test_sampler = LoaderSampler(test_loader_b)


torch.manual_seed(0xBADBEEF)
np.random.seed(0xBADBEEF)
solver.X_fixed = X_sampler.sample(10)
solver.Y_fixed = Y_sampler.sample(10)

solver.X_test_fixed = X_test_sampler.sample(10)
solver.Y_test_fixed = Y_test_sampler.sample(10)

# fetch random validation images for debugging
fetcher = InputFetcher(loaders.src, loaders.ref, args.latent_dim, 'train')
fetcher_val = InputFetcher(loaders.val, None, args.latent_dim, 'val')
inputs_val = next(fetcher_val)

# resume training if necessary
if args.resume_iter > 0:
    solver._load_checkpoint(args.resume_iter)

# remember the initial value of ds weight
initial_lambda_ds = args.lambda_ds

best_l1_cost = np.inf
best_l2_cost = np.inf
best_l1_iter = 0
best_l2_iter = 0

print('Start training...')
start_time = time.time()
for i in range(args.resume_iter, args.total_iters):
    # fetch images and labels
    inputs = next(fetcher)
    x_real, y_org = inputs.x_src, inputs.y_src
    x_ref, x_ref2, y_trg = inputs.x_ref, inputs.x_ref2, inputs.y_ref
    z_trg, z_trg2 = inputs.z_trg, inputs.z_trg2

    masks = nets.fan.get_heatmap(x_real) if args.w_hpf > 0 else None

    # train the discriminator
    d_loss, d_losses_latent = compute_d_loss(
        nets, args, x_real, y_org, y_trg, z_trg=z_trg, masks=masks)
    solver._reset_grad()
    d_loss.backward()
    optims.discriminator.step()

    d_loss, d_losses_ref = compute_d_loss(
        nets, args, x_real, y_org, y_trg, x_ref=x_ref, masks=masks)
    solver._reset_grad()
    d_loss.backward()
    optims.discriminator.step()

    # train the generator
    g_loss, g_losses_latent = compute_g_loss(
        nets, args, x_real, y_org, y_trg, z_trgs=[z_trg, z_trg2], masks=masks)
    
    s_trg = nets.mapping_network(z_trg, y_trg)
    x_fake = nets.generator(x=x_real, s=s_trg, masks=masks)
    g_loss = g_loss + args.lambda_id * F.l1_loss(x_real, x_fake)
    
    solver._reset_grad()
    g_loss.backward()
    optims.generator.step()
    optims.mapping_network.step()
    optims.style_encoder.step()
    
    print(f"G loss = {g_loss.item()}, d loss = {d_loss.item()}, lambda id = {args.lambda_id}")
    solver.writer.add_scalar('g loss',
                              g_loss.item(),
                              i+1)
    solver.writer.add_scalar('d loss',
                             d_loss.item(),
                             i+1)
    

    g_loss, g_losses_ref = compute_g_loss(
        nets, args, x_real, y_org, y_trg, x_refs=[x_ref, x_ref2], masks=masks)
    solver._reset_grad()
    g_loss.backward()
    optims.generator.step()

    # compute moving average of network parameters
    moving_average(nets.generator, nets_ema.generator, beta=0.999)
    moving_average(nets.mapping_network, nets_ema.mapping_network, beta=0.999)
    moving_average(nets.style_encoder, nets_ema.style_encoder, beta=0.999)

    # decay weight for diversity sensitive loss
    if args.lambda_ds > 0:
        args.lambda_ds -= (initial_lambda_ds / args.ds_iter)

    # print out log info
    if i % args.print_every == 0:
        elapsed = time.time() - start_time
        elapsed = str(datetime.timedelta(seconds=elapsed))[:-7]
        log = "Elapsed time [%s], Iteration [%i/%i], " % (elapsed, i+1, args.total_iters)
        all_losses = dict()
        for loss, prefix in zip([d_losses_latent, d_losses_ref, g_losses_latent, g_losses_ref],
                                ['D/latent_', 'D/ref_', 'G/latent_', 'G/ref_']):
            for key, value in loss.items():
                all_losses[prefix + key] = value
        all_losses['G/lambda_ds'] = args.lambda_ds
        log += ' '.join(['%s: [%.4f]' % (key, value) for key, value in all_losses.items()])
        print(log)

    # save model checkpoints
    if i % args.save_every == 0:
        solver._save_checkpoint(step=i+1)

    # compute FID and LPIPS if necessary
    if i % args.eval_every == 0:
        clear_output(wait=True)
        
        nets_ema.mapping_network.eval()
        nets_ema.generator.eval()
        
        print(f"Computing l1 cost")
        l1_cost = calculate_cost(nets_ema, args, trg_idx, X_test_sampler.loader, device,
                   cost_type='l1', verbose=True)
        
        if l1_cost < best_l1_cost:
            best_l1_cost = l1_cost
            best_l1_iter = i
        
        print(f"l1 cost = {l1_cost}, best l1 cost = {best_l1_cost}, best iter = {best_l1_iter}")
        solver.writer.add_scalar('test l1 cost',
                               l1_cost,
                               i + 1)
        
        print(f"Computing l2 cost")
        l2_cost = calculate_cost(nets_ema, args, trg_idx, X_test_sampler.loader, device,
                   cost_type='mse', verbose=True)
        
        if l2_cost < best_l2_cost:
            best_l2_cost = l2_cost
            best_l2_iter = i
        
        print(f"l2 cost = {l2_cost}, best l2 cost = {best_l2_cost}, best iter = {best_l2_iter}")
        solver.writer.add_scalar('test l2 cost',
                               l2_cost,
                               i + 1)
        
        print('Computing FID')
        mu, sigma = get_Z_pushed_loader_stats(nets_ema, args.domains, args, device,
                                              batch_size=37, n_epochs=args.n_epochs)
        fid = calculate_frechet_distance(solver.mu_data, solver.sigma_data, mu, sigma)
        print(f"FID = {fid}, best FID = {solver.BEST_FID}, best iter = {solver.best_iter}")
        solver.writer.add_scalar('test fid',
                               fid,
                               i + 1)
        del mu, sigma
        if fid < solver.BEST_FID:
            solver.BEST_FID = fid
            solver.best_iter = i
        
        print(f"FID = {fid}, best FID = {solver.BEST_FID}, best iter = {solver.best_iter}")

        num_examples = 4
        Y_fakes = []
        Y_test_fakes = []

        for v in range(num_examples):
            N = solver.X_fixed.size(0)
            x_src = solver.X_fixed.to(device)
            y_trg = torch.tensor([final_trg_index] * N).to(device)
            masks = nets.fan.get_heatmap(x_src) if args.w_hpf > 0 else None

            z_trg = torch.randn(N, args.latent_dim).to(device)
            s_trg = nets.mapping_network(z_trg, y_trg)
            x_fake = nets.generator(x=x_src, s=s_trg, masks=masks).detach()
            
            fake_Y_numpy = tensor2img(x_fake)
            Y_fakes.append(fake_Y_numpy)
            
            N = solver.X_test_fixed.size(0)
            x_src = solver.X_test_fixed.to(device)
            y_trg = torch.tensor([final_trg_index] * N).to(device)
            masks = nets.fan.get_heatmap(x_src) if args.w_hpf > 0 else None

            z_trg = torch.randn(N, args.latent_dim).to(device)
            s_trg = nets.mapping_network(z_trg, y_trg)
            x_fake = nets.generator(x=x_src, s=s_trg, masks=masks).detach()

            fake_Y_test_numpy = tensor2img(x_fake)
            Y_test_fakes.append(fake_Y_test_numpy)

        real_X_numpy = tensor2img(solver.X_fixed)
        real_X_test_numpy = tensor2img(solver.X_test_fixed)
        real_Y_numpy = tensor2img(solver.Y_fixed)
        real_Y_test_numpy = tensor2img(solver.Y_test_fixed)

        X_tensors = [real_X_numpy, real_X_test_numpy]
        Y_tensors = [real_Y_numpy, real_Y_test_numpy]

        Y_fakes_tensors = [Y_fakes, Y_test_fakes]

        modes = ["train", "test"]

        print(f"Plotting, iter = {i}")

        for t in range(2):
            print(f"mode = {modes[t]}")
            fig, axes = plt.subplots(6, 10, figsize=(15, 9), dpi=150)
            X_tensor = X_tensors[t]
            Y_tensor = Y_tensors[t]
            Y_fake_tensor = Y_fakes_tensors[t]

            for j in range(10):
                axes[0][j].imshow(X_tensor[j])
                axes[0][j].get_xaxis().set_visible(False)
                axes[0][j].get_yaxis().set_visible(False)

            for j in range(10):
                axes[5][j].imshow(Y_tensor[j])
                axes[5][j].get_xaxis().set_visible(False)
                axes[5][j].get_yaxis().set_visible(False)

            for s in range(4):
                for j in range(10):
                    cur_img = Y_fake_tensor[s][j]

                    axes[s + 1][j].imshow(cur_img)
                    axes[s + 1][j].get_xaxis().set_visible(False)
                    axes[s + 1][j].get_yaxis().set_visible(False)

            plt.show(fig)
            solver.writer.add_figure(f'Step {i + 1}, {modes[t]}',
                                     fig,
                                     global_step=i + 1)
            plt.close(fig)
            
        nets_ema.mapping_network.train()
        nets_ema.generator.train()
# Out:
# Start training...
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:97871 [0] NCCL INFO Bootstrap : Using eth0:172.16.4.60<0>
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:97871 [0] NCCL INFO NET/Plugin : No plugin found (libnccl-net.so), using internal implementation
#
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:97871 [0] misc/ibvwrap.cc:212 NCCL WARN Call to ibv_open_device failed
#
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:97871 [0] transport/net_ib.cc:149 NCCL WARN NET/IB : Unable to open device mlx5_0
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:97871 [0] NCCL INFO NET/IB : No device found.
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:97871 [0] NCCL INFO NET/Socket : Using [0]eth0:172.16.4.60<0>
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:97871 [0] NCCL INFO Using network Socket
# NCCL version 2.10.3+cuda10.2
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Trees [0] 4/-1/-1->5->7 [1] 4/-1/-1->5->7 [2] 7/-1/-1->5->4 [3] 7/-1/-1->5->4 [4] 6/-1/-1->5->1 [5] 1/-1/-1->5->6 [6] 4/-1/-1->5->7 [7] 4/-1/-1->5->7 [8] 7/-1/-1->5->4 [9] 7/-1/-1->5->4 [10] 6/-1/-1->5->1 [11] 1/-1/-1->5->6
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Setting affinity for GPU 5 to ff,ffc0000f,fffc0000
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98632 [6] NCCL INFO Trees [0] 2/-1/-1->6->4 [1] 2/-1/-1->6->4 [2] 4/-1/-1->6->2 [3] 4/-1/-1->6->2 [4] 7/-1/-1->6->5 [5] 5/-1/-1->6->7 [6] 2/-1/-1->6->4 [7] 2/-1/-1->6->4 [8] 4/-1/-1->6->2 [9] 4/-1/-1->6->2 [10] 7/-1/-1->6->5 [11] 5/-1/-1->6->7
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98632 [6] NCCL INFO Setting affinity for GPU 6 to ff,ffc0000f,fffc0000
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98633 [7] NCCL INFO Trees [0] 5/-1/-1->7->3 [1] 5/-1/-1->7->3 [2] 3/-1/-1->7->5 [3] 3/-1/-1->7->5 [4] 4/-1/-1->7->6 [5] 6/-1/-1->7->4 [6] 5/-1/-1->7->3 [7] 5/-1/-1->7->3 [8] 3/-1/-1->7->5 [9] 3/-1/-1->7->5 [10] 4/-1/-1->7->6 [11] 6/-1/-1->7->4
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98633 [7] NCCL INFO Setting affinity for GPU 7 to ff,ffc0000f,fffc0000
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 00/12 :    0   1   3   7   5   4   6   2
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 01/12 :    0   1   3   7   5   4   6   2
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 02/12 :    0   2   6   4   5   7   3   1
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 03/12 :    0   2   6   4   5   7   3   1
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 04/12 :    0   3   2   1   5   6   7   4
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 05/12 :    0   4   7   6   5   1   2   3
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 06/12 :    0   1   3   7   5   4   6   2
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 07/12 :    0   1   3   7   5   4   6   2
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 08/12 :    0   2   6   4   5   7   3   1
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 09/12 :    0   2   6   4   5   7   3   1
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 10/12 :    0   3   2   1   5   6   7   4
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 11/12 :    0   4   7   6   5   1   2   3
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Trees [0] 1/-1/-1->0->-1 [1] 1/-1/-1->0->-1 [2] 2/-1/-1->0->-1 [3] 2/-1/-1->0->-1 [4] 3/-1/-1->0->-1 [5] 4/-1/-1->0->-1 [6] 1/-1/-1->0->-1 [7] 1/-1/-1->0->-1 [8] 2/-1/-1->0->-1 [9] 2/-1/-1->0->-1 [10] 3/-1/-1->0->-1 [11] 4/-1/-1->0->-1
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Setting affinity for GPU 0 to 3ffff0,0003ffff
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Trees [0] 3/-1/-1->1->0 [1] 3/-1/-1->1->0 [2] -1/-1/-1->1->3 [3] -1/-1/-1->1->3 [4] 5/-1/-1->1->2 [5] 2/-1/-1->1->5 [6] 3/-1/-1->1->0 [7] 3/-1/-1->1->0 [8] -1/-1/-1->1->3 [9] -1/-1/-1->1->3 [10] 5/-1/-1->1->2 [11] 2/-1/-1->1->5
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Setting affinity for GPU 1 to 3ffff0,0003ffff
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98628 [2] NCCL INFO Trees [0] -1/-1/-1->2->6 [1] -1/-1/-1->2->6 [2] 6/-1/-1->2->0 [3] 6/-1/-1->2->0 [4] 1/-1/-1->2->3 [5] 3/-1/-1->2->1 [6] -1/-1/-1->2->6 [7] -1/-1/-1->2->6 [8] 6/-1/-1->2->0 [9] 6/-1/-1->2->0 [10] 1/-1/-1->2->3 [11] 3/-1/-1->2->1
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98628 [2] NCCL INFO Setting affinity for GPU 2 to 3ffff0,0003ffff
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98629 [3] NCCL INFO Trees [0] 7/-1/-1->3->1 [1] 7/-1/-1->3->1 [2] 1/-1/-1->3->7 [3] 1/-1/-1->3->7 [4] 2/-1/-1->3->0 [5] -1/-1/-1->3->2 [6] 7/-1/-1->3->1 [7] 7/-1/-1->3->1 [8] 1/-1/-1->3->7 [9] 1/-1/-1->3->7 [10] 2/-1/-1->3->0 [11] -1/-1/-1->3->2
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98629 [3] NCCL INFO Setting affinity for GPU 3 to 3ffff0,0003ffff
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Trees [0] 6/-1/-1->4->5 [1] 6/-1/-1->4->5 [2] 5/-1/-1->4->6 [3] 5/-1/-1->4->6 [4] -1/-1/-1->4->7 [5] 7/-1/-1->4->0 [6] 6/-1/-1->4->5 [7] 6/-1/-1->4->5 [8] 5/-1/-1->4->6 [9] 5/-1/-1->4->6 [10] -1/-1/-1->4->7 [11] 7/-1/-1->4->0
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Setting affinity for GPU 4 to ff,ffc0000f,fffc0000
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 02 : 4[b5000] -> 5[be000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 03 : 4[b5000] -> 5[be000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 08 : 4[b5000] -> 5[be000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98628 [2] NCCL INFO Channel 05 : 2[5b000] -> 3[5f000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 00 : 0[2d000] -> 1[32000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98632 [6] NCCL INFO Channel 04 : 6[e1000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 09 : 4[b5000] -> 5[be000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98628 [2] NCCL INFO Channel 11 : 2[5b000] -> 3[5f000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98632 [6] NCCL INFO Channel 10 : 6[e1000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 01 : 0[2d000] -> 1[32000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 06 : 0[2d000] -> 1[32000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Channel 05 : 1[32000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 07 : 0[2d000] -> 1[32000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Channel 11 : 1[32000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 02 : 0[2d000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Channel 00 : 1[32000] -> 3[5f000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 03 : 0[2d000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Channel 01 : 1[32000] -> 3[5f000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 04 : 5[be000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 08 : 0[2d000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Channel 06 : 1[32000] -> 3[5f000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 10 : 5[be000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Channel 07 : 1[32000] -> 3[5f000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 09 : 0[2d000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 02 : 5[be000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 00 : 4[b5000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 04 : 0[2d000] -> 3[5f000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 03 : 5[be000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 01 : 4[b5000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 10 : 0[2d000] -> 3[5f000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 08 : 5[be000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 06 : 4[b5000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 09 : 5[be000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 07 : 4[b5000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Channel 04 : 1[32000] -> 5[be000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98628 [2] NCCL INFO Channel 02 : 2[5b000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO Channel 10 : 1[32000] -> 5[be000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 05 : 4[b5000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98628 [2] NCCL INFO Channel 03 : 2[5b000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 05 : 5[be000] -> 1[32000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 11 : 4[b5000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98628 [2] NCCL INFO Channel 08 : 2[5b000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 11 : 5[be000] -> 1[32000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98628 [2] NCCL INFO Channel 09 : 2[5b000] -> 6[e1000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 05 : 0[2d000] -> 4[b5000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98632 [6] NCCL INFO Channel 00 : 6[e1000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98629 [3] NCCL INFO Channel 00 : 3[5f000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 11 : 0[2d000] -> 4[b5000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 04 : 4[b5000] -> 0[2d000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98632 [6] NCCL INFO Channel 01 : 6[e1000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98629 [3] NCCL INFO Channel 01 : 3[5f000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 10 : 4[b5000] -> 0[2d000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98632 [6] NCCL INFO Channel 06 : 6[e1000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98629 [3] NCCL INFO Channel 06 : 3[5f000] -> 7[e9000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98632 [6] NCCL INFO Channel 07 : 6[e1000] -> 2[5b000] via P2P/direct pointer
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98629 [3] NCCL INFO Channel
]
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 06 : 5[be000] -> 3[5f000] via P2P/indirect/7[e9000]
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 06 : 0[2d000] -> 6[e1000] via P2P/indirect/2[5b000]
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO Channel 14 : 5[be000] -> 3[5f000] via P2P/indirect/7[e9000]
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 14 : 0[2d000] -> 6[e1000] via P2P/indirect/2[5b000]
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 07 : 0[2d000] -> 7[e9000] via P2P/indirect/3[5f000]
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 07 : 4[b5000] -> 3[5f000] via P2P/indirect/7[e9000]
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO Channel 15 : 4[b5000] -> 3[5f000] via P2P/indirect/7[e9000]
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO Channel 15 : 0[2d000] -> 7[e9000] via P2P/indirect/3[5f000]
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98629 [3] NCCL INFO comm 0x7efa60001200 rank 3 nranks 8 cudaDev 3 busId 5f000 - Init COMPLETE
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98627 [1] NCCL INFO comm 0x7efa68001200 rank 1 nranks 8 cudaDev 1 busId 32000 - Init COMPLETE
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98633 [7] NCCL INFO comm 0x7efa50001200 rank 7 nranks 8 cudaDev 7 busId e9000 - Init COMPLETE
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98626 [0] NCCL INFO comm 0x7efa64001200 rank 0 nranks 8 cudaDev 0 busId 2d000 - Init COMPLETE
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98630 [4] NCCL INFO comm 0x7efa54001200 rank 4 nranks 8 cudaDev 4 busId b5000 - Init COMPLETE
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98631 [5] NCCL INFO comm 0x7efa58001200 rank 5 nranks 8 cudaDev 5 busId be000 - Init COMPLETE
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98632 [6] NCCL INFO comm 0x7efa4c001200 rank 6 nranks 8 cudaDev 6 busId e1000 - Init COMPLETE
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:98628 [2] NCCL INFO comm 0x7efa5c001200 rank 2 nranks 8 cudaDev 2 busId 5b000 - Init COMPLETE
# modelarts-job-f641f1c4-55f3-427a-955d-c14b338bafed-worker-0:97871:97871 [0] NCCL INFO Launch mode Parallel
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 84
#      81 masks = nets.fan.get_heatmap(x_real) if args.w_hpf > 0 else None
#      83 # train the discriminator
# ---> 84 d_loss, d_losses_latent = compute_d_loss(
#      85     nets, args, x_real, y_org, y_trg, z_trg=z_trg, masks=masks)
#      86 solver._reset_grad()
#      87 d_loss.backward()
#
# File /cache/selikhanovych/extremal_ot/stargan-v2/core/my_solver.py:370, in compute_d_loss(nets, args, x_real, y_org, y_trg, z_trg, x_ref, masks)
#     368 out = nets.discriminator(x_real, y_org)
#     369 loss_real = adv_loss(out, 1)
# --> 370 loss_reg = r1_reg(out, x_real)
#     372 # with fake images
#     373 with torch.no_grad():
#
# File /cache/selikhanovych/extremal_ot/stargan-v2/core/my_solver.py:448, in r1_reg(d_out, x_in)
#     445 def r1_reg(d_out, x_in):
#     446     # zero-centered gradient penalty for real images
#     447     batch_size = x_in.size(0)
# --> 448     grad_dout = torch.autograd.grad(
#     449         outputs=d_out.sum(), inputs=x_in,
#     450         create_graph=True, retain_graph=True, only_inputs=True
#     451     )[0]
#     452     grad_dout2 = grad_dout.pow(2)
#     453     assert(grad_dout2.size() == x_in.size())
#
# File /cache/selikhanovych/miniconda3/envs/ot_env/lib/python3.8/site-packages/torch/autograd/__init__.py:276, in grad(outputs, inputs, grad_outputs, retain_graph, create_graph, only_inputs, allow_unused, is_grads_batched)
#     274     return _vmap_internals._vmap(vjp, 0, 0, allow_none_pass_through=True)(grad_outputs_)
#     275 else:
# --> 276     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     277         t_outputs, grad_outputs_, retain_graph, create_graph, t_inputs,
#     278         allow_unused, accumulate_grad=False)
#
# KeyboardInterrupt:
