# %%
from PIL import Image
import numpy as np

path = "/cache/selikhanovych/ot/data/dtd2shoes_train/shoes/0.png"
Image.open(path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x128 at 0x7F6280113C50>

# %%
np.array(Image.open(path)).shape
# Out:
# (128, 128, 3)

# %%
from PIL import Image
import numpy as np

path = "/cache/selikhanovych/ot/data/dtd2shoes_train/shoes/0.png"
Image.open(path)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=128x128 at 0x7F604A8CD400>
